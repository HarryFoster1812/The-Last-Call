# %%
import pandas as pd

# %%
brews = pd.read_csv('0f5ea72c-6112-484f-997f-8cb8bd84f725.csv')

# %%
brews.columns = ['id', 'Type', 'Name', 'Brand']

# %%
brews
# Out:
#         id               Type  \
# 0        1  Beer Manufacturer
# 1        2  Beer Manufacturer
# 2        3  Beer Manufacturer
# 3        4  Beer Manufacturer
# 4        5  Beer Manufacturer
# ...    ...                ...
# 1588  1589        Microbrewer
# 1589  1590        Microbrewer
# 1590  1591        Microbrewer
# 1591  1592       Microbrewers
# 1592  1593         Mirobrewer
#
#                                                    Name  \
# 0     9664483 Canada Inc. o/a Goose Island Brewing C...
# 1     Amsterdam Brewing Co. Limited o/a Amsterdam Br...
# 2     Amsterdam Brewing Co. Limited o/a Amsterdam Br...
# 3     Amsterdam Brewing Co. Limited o/a Amsterdam Br...
# 4     Amsterdam Brewing Co. Limited o/a Amsterdam Br...
# ...                                                 ...
# 1588                       Wrinkly Bear Brewing Company
# 1589  Wrinkly Bear Brewing Company Inc. o/a Wrinkly ...
# 1590  Yates Street Brewing Company Inc. o/a Coldbrea...
# ...

# %%
brew_db = pd.read_csv('brewery.csv')
brew_db
# Out:
#       brewery_id                            brewery_name
# 0              1                Plzensky Prazdroj, a. s.
# 1              2             Yellow Rose Brewing Company
# 2              3                       Abita Brewing Co.
# 3              4                Allagash Brewing Company
# 4              5  Yakima Brewing Co. / Bert Grant's Ales
# ...          ...                                     ...
# 5835       27945         The Foundry / Cantebury Brewers
# 5836       27980                                Tap East
# 5837       27984                 Shady Lady Beer Pty Ltd
# 5838       28000                       Brouwerij Maximus
# 5839       28003                       Bennexer Brauhaus
#
# [5840 rows x 2 columns]
